# %%
import pandas as pd

# %%
covid_df = pd.read_csv('C:\\Users\\HP\\Documents\\covid19_eco.csv')

# %%
covid_df.head()
# Out:
#           ID        DATE  CONFIRMED_CASE  NEW_CASE  TOTAL_CASE  DEATH_CASE  \
# 0  COV-NG001  27/02/2020             0.0       1.0         1.0         0.0
# 1  COV-NG002  28/02/2020             1.0       0.0         1.0         0.0
# 2  COV-NG003  29/02/2020             1.0       0.0         1.0         0.0
# 3  COV-NG004  01/03/2020             1.0       0.0         1.0         0.0
# 4  COV-NG005  02/03/2020             1.0       0.0         1.0         0.0
#
#    GLOBAL_CONFIRMED_CASE  PERCENTAGE_GCC GLOBAL_NEW_CASES  PERCENTAGE_GNC  \
# 0                82294.0        0.001215             1185        0.084388
# 1                83652.0        0.001195             1358        0.000000
# 2                84403.0        0.001185             1753        0.000000
# 3                87137.0        0.001148             1739        0.000000
# 4                88948.0        0.001124             1806        0.000000
#
# ...

# %%
covid_df
# Out:
#             ID        DATE  CONFIRMED_CASE  NEW_CASE  TOTAL_CASE  DEATH_CASE  \
# 0    COV-NG001  27/02/2020             0.0       1.0         1.0         0.0
# 1    COV-NG002  28/02/2020             1.0       0.0         1.0         0.0
# 2    COV-NG003  29/02/2020             1.0       0.0         1.0         0.0
# 3    COV-NG004  01/03/2020             1.0       0.0         1.0         0.0
# 4    COV-NG005  02/03/2020             1.0       0.0         1.0         0.0
# ..         ...         ...             ...       ...         ...         ...
# 109  COV-NG110  15/06/2020         16112.0     573.0     16685.0         4.0
# 110  COV-NG111  16/06/2020         16685.0     490.0     17175.0        31.0
# 111  COV-NG112  17/06/2020         17175.0     587.0     17762.0        14.0
# 112  COV-NG113  18/06/2020         17762.0     745.0     18507.0         6.0
# 113        NaN         NaN             NaN       NaN         NaN         NaN
#
# ...

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     113 non-null    object
#  1   DATE                   113 non-null    object
#  2   CONFIRMED_CASE         113 non-null    float64
#  3   NEW_CASE               113 non-null    float64
#  4   TOTAL_CASE             113 non-null    float64
#  5   DEATH_CASE             113 non-null    float64
#  6   GLOBAL_CONFIRMED_CASE  113 non-null    float64
#  7   PERCENTAGE_GCC         113 non-null    float64
#  8   GLOBAL_NEW_CASES       113 non-null    object
#  9   PERCENTAGE_GNC         113 non-null    float64
#  10  GLOBAL_DEATH_CASES     113 non-null    float64
#  11  PERCENTAGE_GDC         113 non-null    float64
#  12  WEATHER                113 non-null    float64
#  13  BUYING_RATE            113 non-null    float64
# ...

# %%
covid_df.describe()
# Out:
#        CONFIRMED_CASE    NEW_CASE    TOTAL_CASE  DEATH_CASE  \
# count      113.000000  113.000000    113.000000  113.000000
# mean      3857.460177  163.769912   4021.230088    4.203540
# std       5070.394409  185.477521   5240.724514    5.423427
# min          0.000000    0.000000      1.000000    0.000000
# 25%         46.000000    6.000000     65.000000    0.000000
# 50%        874.000000   91.000000    982.000000    2.000000
# 75%       6696.000000  265.000000   7035.000000    7.000000
# max      17762.000000  745.000000  18507.000000   31.000000
#
#        GLOBAL_CONFIRMED_CASE  PERCENTAGE_GCC  PERCENTAGE_GNC  \
# count           1.130000e+02      113.000000      113.000000
# mean            2.954492e+06        0.075050        0.162695
# std             2.511797e+06        0.073562        0.160561
# min             8.229400e+04        0.000981        0.000000
# 25%             4.626840e+05        0.013748        0.015066
# ...

# %%
covid_df.columns
# Out:
# Index(['ID', 'DATE', 'CONFIRMED_CASE', 'NEW_CASE', 'TOTAL_CASE', 'DEATH_CASE',
#        'GLOBAL_CONFIRMED_CASE', 'PERCENTAGE_GCC', 'GLOBAL_NEW_CASES',
#        'PERCENTAGE_GNC', 'GLOBAL_DEATH_CASES', 'PERCENTAGE_GDC', 'WEATHER',
#        'BUYING_RATE', 'CENTRAL_RATE', 'SELLING_RATE', 'SHARE_INDEX',
#        'OIL_PRICE', 'GROSS_RESERVES', 'LIQUID_RESERVES'],
#       dtype='object')

# %%
covid_df.shape
# Out:
# (114, 20)

# %%
covid_df['CENTRAL_RATE']
# Out:
# 0      306.45
# 1      306.45
# 2      306.45
# 3      306.45
# 4      306.50
#         ...
# 109    360.50
# 110    360.50
# 111    360.50
# 112    360.50
# 113       NaN
# Name: CENTRAL_RATE, Length: 114, dtype: float64

# %%
covid_df.CENTRAL_RATE
# Out:
# 0      306.45
# 1      306.45
# 2      306.45
# 3      306.45
# 4      306.50
#         ...
# 109    360.50
# 110    360.50
# 111    360.50
# 112    360.50
# 113       NaN
# Name: CENTRAL_RATE, Length: 114, dtype: float64

# %%
covid_df['WEATHER'][100]
# Out:
# 33.0

# %%
covid_df.at[100, 'WEATHER']
# Out:
# 33.0

# %%
start_df = covid_df[['ID', 'DATE', 'CONFIRMED_CASE', 'NEW_CASE']]
start_df
# Out:
#             ID        DATE  CONFIRMED_CASE  NEW_CASE
# 0    COV-NG001  27/02/2020             0.0       1.0
# 1    COV-NG002  28/02/2020             1.0       0.0
# 2    COV-NG003  29/02/2020             1.0       0.0
# 3    COV-NG004  01/03/2020             1.0       0.0
# 4    COV-NG005  02/03/2020             1.0       0.0
# ..         ...         ...             ...       ...
# 109  COV-NG110  15/06/2020         16112.0     573.0
# 110  COV-NG111  16/06/2020         16685.0     490.0
# 111  COV-NG112  17/06/2020         17175.0     587.0
# 112  COV-NG113  18/06/2020         17762.0     745.0
# 113        NaN         NaN             NaN       NaN
#
# [114 rows x 4 columns]

# %%
covid_df_copy = covid_df.copy()

# %%
covid_df.loc[100]
# Out:
# ID                           COV-NG101
# DATE                        06/06/2020
# CONFIRMED_CASE                 11864.0
# NEW_CASE                         389.0
# TOTAL_CASE                     12253.0
# DEATH_CASE                         9.0
# GLOBAL_CONFIRMED_CASE        6663304.0
# PERCENTAGE_GCC                0.183888
# GLOBAL_NEW_CASES                127950
# PERCENTAGE_GNC                0.304025
# GLOBAL_DEATH_CASES            392802.0
# PERCENTAGE_GDC                0.002291
# WEATHER                           33.0
# BUYING_RATE                      360.0
# CENTRAL_RATE                     360.5
# SELLING_RATE                     361.0
# SHARE_INDEX                   25016.30
# OIL_PRICE                         42.3
# GROSS_RESERVES           36549648801.0
# LIQUID_RESERVES          35952810234.0
# Name: 100, dtype: object

# %%
covid_df.head(20)
# Out:
#            ID        DATE  CONFIRMED_CASE  NEW_CASE  TOTAL_CASE  DEATH_CASE  \
# 0   COV-NG001  27/02/2020             0.0       1.0         1.0         0.0
# 1   COV-NG002  28/02/2020             1.0       0.0         1.0         0.0
# 2   COV-NG003  29/02/2020             1.0       0.0         1.0         0.0
# 3   COV-NG004  01/03/2020             1.0       0.0         1.0         0.0
# 4   COV-NG005  02/03/2020             1.0       0.0         1.0         0.0
# 5   COV-NG006  03/03/2020             1.0       0.0         1.0         0.0
# 6   COV-NG007  04/03/2020             1.0       0.0         1.0         0.0
# 7   COV-NG008  05/03/2020             1.0       0.0         1.0         0.0
# 8   COV-NG009  06/03/2020             1.0       0.0         1.0         0.0
# 9   COV-NG010  07/03/2020             1.0       0.0         1.0         0.0
# 10  COV-NG011  08/03/2020             1.0       1.0         2.0         0.0
# ...

# %%
covid_df.tail(10)
# Out:
#             ID        DATE  CONFIRMED_CASE  NEW_CASE  TOTAL_CASE  DEATH_CASE  \
# 104  COV-NG105  10/06/2020         13491.0     409.0     13900.0        17.0
# 105  COV-NG106  11/06/2020         13900.0     681.0     14581.0         5.0
# 106  COV-NG107  12/06/2020         14581.0     627.0     15208.0        12.0
# 107  COV-NG108  13/06/2020         15208.0     501.0     15709.0         8.0
# 108  COV-NG109  14/06/2020         15709.0     403.0     16112.0        13.0
# 109  COV-NG110  15/06/2020         16112.0     573.0     16685.0         4.0
# 110  COV-NG111  16/06/2020         16685.0     490.0     17175.0        31.0
# 111  COV-NG112  17/06/2020         17175.0     587.0     17762.0        14.0
# 112  COV-NG113  18/06/2020         17762.0     745.0     18507.0         6.0
# 113        NaN         NaN             NaN       NaN         NaN         NaN
#
#      GLOBAL_CONFIRMED_CASE  PERCENTAGE_GCC GLOBAL_NEW_CASES  PERCENTAGE_GNC  \
# ...

# %%
covid_df.at[0, 'WEATHER']
# Out:
# 37.0

# %%
type(covid_df.at[0, 'WEATHER'])
# Out:
# numpy.float64

# %%
covid_df.PERCENTAGE_GDC.first_valid_index()
# Out:
# 0

# %%
covid_df.loc[55:100]
# Out:
#             ID        DATE  CONFIRMED_CASE  NEW_CASE  TOTAL_CASE  DEATH_CASE  \
# 55   COV-NG056  22/04/2020           783.0      91.0       874.0         3.0
# 56   COV-NG057  23/04/2020           874.0     108.0       982.0         3.0
# 57   COV-NG058  24/04/2020           982.0     114.0      1096.0         1.0
# 58   COV-NG059  25/04/2020          1096.0      87.0      1183.0         3.0
# 59   COV-NG060  26/04/2020          1183.0      91.0      1274.0         5.0
# 60   COV-NG061  27/04/2020          1274.0      64.0      1338.0         0.0
# 61   COV-NG062  28/04/2020          1338.0     195.0      1533.0         4.0
# 62   COV-NG063  29/04/2020          1533.0     196.0      1729.0         7.0
# 63   COV-NG064  30/04/2020          1729.0     204.0      1933.0         7.0
# 64   COV-NG065  01/05/2020          1933.0     238.0      2171.0        10.0
# 65   COV-NG066  02/05/2020          2171.0     220.0      2391.0        17.0
# ...

# %%
covid_df.sample(15)
# Out:
#             ID        DATE  CONFIRMED_CASE  NEW_CASE  TOTAL_CASE  DEATH_CASE  \
# 59   COV-NG060  26/04/2020          1183.0      91.0      1274.0         5.0
# 94   COV-NG095  31/05/2020          9874.0     307.0     10181.0        14.0
# 74   COV-NG075  11/05/2020          4403.0     242.0      4645.0        10.0
# 76   COV-NG077  13/05/2020          4791.0     184.0      4975.0         6.0
# 54   COV-NG055  21/04/2020           666.0     117.0       783.0         3.0
# 41   COV-NG042  08/04/2020           254.0      22.0       276.0         0.0
# 63   COV-NG064  30/04/2020          1729.0     204.0      1933.0         7.0
# 49   COV-NG050  16/04/2020           407.0      35.0       442.0         1.0
# 27   COV-NG028  25/03/2020            36.0      10.0        46.0         0.0
# 18   COV-NG019  16/03/2020             2.0       1.0         3.0         0.0
# 106  COV-NG107  12/06/2020         14581.0     627.0     15208.0        12.0
# ...

# %%
total_CONFIRMED_CASE = covid_df.CONFIRMED_CASE.sum()
total_CONFIRMED_CASE
# Out:
# 435893.0

# %%
total_DEATH_CASE = covid_df.DEATH_CASE.sum()
total_DEATH_CASE
# Out:
# 475.0

# %%
total_NEW_CASE = covid_df.NEW_CASE.sum()
total_NEW_CASE
# Out:
# 18506.0

# %%
death_rate = total_DEATH_CASE / total_NEW_CASE
death_rate
# Out:
# 0.02566735112936345

# %%
death_ratee = covid_df.DEATH_CASE.sum() / covid_df.NEW_CASE.sum()
death_ratee
# Out:
# 0.02566735112936345

# %%
initial_cases = 935310
total_cases = initial_cases + covid_df.NEW_CASE.sum()
total_cases
# Out:
# 953816.0

# %%
positive_rate = total_NEW_CASE / total_cases
positive_rate
# Out:
# 0.019402064968505457

# %%
high_total_cases = covid_df.TOTAL_CASE > 10000
high_total_cases
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 109     True
# 110     True
# 111     True
# 112     True
# 113    False
# Name: TOTAL_CASE, Length: 114, dtype: bool

# %%
high_total_cases.sum()
# Out:
# 19

# %%
high_total_cases.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 114 entries, 0 to 113
# Series name: TOTAL_CASE
# Non-Null Count  Dtype
# --------------  -----
# 114 non-null    bool
# dtypes: bool(1)
# memory usage: 246.0 bytes

# %%
covid_df[high_total_cases]
# Out:
#             ID        DATE  CONFIRMED_CASE  NEW_CASE  TOTAL_CASE  DEATH_CASE  \
# 94   COV-NG095  31/05/2020          9874.0     307.0     10181.0        14.0
# 95   COV-NG096  01/06/2020         10181.0     416.0     10597.0        12.0
# 96   COV-NG097  02/06/2020         10597.0     241.0     10838.0        15.0
# 97   COV-NG098  03/06/2020         10838.0     348.0     11186.0         1.0
# 98   COV-NG099  04/06/2020         11186.0     350.0     11536.0         8.0
# 99   COV-NG100  05/06/2020         11536.0     328.0     11864.0        10.0
# 100  COV-NG101  06/06/2020         11864.0     389.0     12253.0         9.0
# 101  COV-NG102  07/06/2020         12253.0     260.0     12513.0        12.0
# 102  COV-NG103  08/06/2020         12513.0     315.0     12828.0         7.0
# 103  COV-NG104  09/06/2020         12828.0     663.0     13491.0         4.0
# 104  COV-NG105  10/06/2020         13491.0     409.0     13900.0        17.0
# ...

# %%
high_total = covid_df[covid_df.TOTAL_CASE > 10000]
high_total
# Out:
#             ID        DATE  CONFIRMED_CASE  NEW_CASE  TOTAL_CASE  DEATH_CASE  \
# 94   COV-NG095  31/05/2020          9874.0     307.0     10181.0        14.0
# 95   COV-NG096  01/06/2020         10181.0     416.0     10597.0        12.0
# 96   COV-NG097  02/06/2020         10597.0     241.0     10838.0        15.0
# 97   COV-NG098  03/06/2020         10838.0     348.0     11186.0         1.0
# 98   COV-NG099  04/06/2020         11186.0     350.0     11536.0         8.0
# 99   COV-NG100  05/06/2020         11536.0     328.0     11864.0        10.0
# 100  COV-NG101  06/06/2020         11864.0     389.0     12253.0         9.0
# 101  COV-NG102  07/06/2020         12253.0     260.0     12513.0        12.0
# 102  COV-NG103  08/06/2020         12513.0     315.0     12828.0         7.0
# 103  COV-NG104  09/06/2020         12828.0     663.0     13491.0         4.0
# 104  COV-NG105  10/06/2020         13491.0     409.0     13900.0        17.0
# ...

# %%
from IPython.display import display
with pd.option_context('display.max_rows', 100):
    display(covid_df[covid_df.new_cases > 1000])
# Out:
#             ID        DATE  CONFIRMED_CASE  NEW_CASE  TOTAL_CASE  DEATH_CASE  \
# 0    COV-NG001  27/02/2020             0.0       1.0         1.0         0.0
# 1    COV-NG002  28/02/2020             1.0       0.0         1.0         0.0
# 2    COV-NG003  29/02/2020             1.0       0.0         1.0         0.0
# 3    COV-NG004  01/03/2020             1.0       0.0         1.0         0.0
# 4    COV-NG005  02/03/2020             1.0       0.0         1.0         0.0
# ..         ...         ...             ...       ...         ...         ...
# 109  COV-NG110  15/06/2020         16112.0     573.0     16685.0         4.0
# 110  COV-NG111  16/06/2020         16685.0     490.0     17175.0        31.0
# 111  COV-NG112  17/06/2020         17175.0     587.0     17762.0        14.0
# 112  COV-NG113  18/06/2020         17762.0     745.0     18507.0         6.0
# 113        NaN         NaN             NaN       NaN         NaN         NaN
#
# ...

# %%
from IPython.display import display
with pd.option_context('display.max_rows', 100):
    display(covid_df[covid_df.NEW_CASE>10])
# Out:
#             ID        DATE  CONFIRMED_CASE  NEW_CASE  TOTAL_CASE  DEATH_CASE  \
# 28   COV-NG029  26/03/2020            46.0      19.0        65.0         0.0
# 30   COV-NG031  28/03/2020            70.0      27.0        97.0         0.0
# 31   COV-NG032  29/03/2020            97.0      14.0       111.0         0.0
# 32   COV-NG033  30/03/2020           111.0      20.0       131.0         1.0
# 34   COV-NG035  01/04/2020           139.0      35.0       174.0         0.0
# 36   COV-NG037  03/04/2020           184.0      25.0       209.0         0.0
# 38   COV-NG039  05/04/2020           214.0      18.0       232.0         0.0
# 40   COV-NG041  07/04/2020           238.0      16.0       254.0         1.0
# 41   COV-NG042  08/04/2020           254.0      22.0       276.0         0.0
# 42   COV-NG043  09/04/2020           276.0      12.0       288.0         1.0
# 43   COV-NG044  10/04/2020           288.0      17.0       305.0         0.0
# ...

# %%
high_ratio_df = covid_df[covid_df.NEW_CASE / covid_df.TOTAL_CASE > positive_rate]
high_ratio_df
# Out:
#             ID        DATE  CONFIRMED_CASE  NEW_CASE  TOTAL_CASE  DEATH_CASE  \
# 0    COV-NG001  27/02/2020             0.0       1.0         1.0         0.0
# 10   COV-NG011  08/03/2020             1.0       1.0         2.0         0.0
# 18   COV-NG019  16/03/2020             2.0       1.0         3.0         0.0
# 20   COV-NG021  18/03/2020             3.0       5.0         8.0         0.0
# 21   COV-NG022  19/03/2020             8.0       4.0        12.0         0.0
# ..         ...         ...             ...       ...         ...         ...
# 108  COV-NG109  14/06/2020         15709.0     403.0     16112.0        13.0
# 109  COV-NG110  15/06/2020         16112.0     573.0     16685.0         4.0
# 110  COV-NG111  16/06/2020         16685.0     490.0     17175.0        31.0
# 111  COV-NG112  17/06/2020         17175.0     587.0     17762.0        14.0
# 112  COV-NG113  18/06/2020         17762.0     745.0     18507.0         6.0
#
# ...

# %%
covid_df['positive_rate'] = covid_df.NEW_CASE / covid_df.TOTAL_CASE 
covid_df
# Out:
#             ID        DATE  CONFIRMED_CASE  NEW_CASE  TOTAL_CASE  DEATH_CASE  \
# 0    COV-NG001  27/02/2020             0.0       1.0         1.0         0.0
# 1    COV-NG002  28/02/2020             1.0       0.0         1.0         0.0
# 2    COV-NG003  29/02/2020             1.0       0.0         1.0         0.0
# 3    COV-NG004  01/03/2020             1.0       0.0         1.0         0.0
# 4    COV-NG005  02/03/2020             1.0       0.0         1.0         0.0
# ..         ...         ...             ...       ...         ...         ...
# 109  COV-NG110  15/06/2020         16112.0     573.0     16685.0         4.0
# 110  COV-NG111  16/06/2020         16685.0     490.0     17175.0        31.0
# 111  COV-NG112  17/06/2020         17175.0     587.0     17762.0        14.0
# 112  COV-NG113  18/06/2020         17762.0     745.0     18507.0         6.0
# 113        NaN         NaN             NaN       NaN         NaN         NaN
#
# ...

# %%
covid_df.positive_rate.plot(title='Positive Rate')
# Out:
# <Axes: title={'center': 'Positive Rate'}>

# %%
covid_df.positive_rate.plot(title='Positive Rate', kind = 'bar')
# Out:
# <Axes: title={'center': 'Positive Rate'}>
